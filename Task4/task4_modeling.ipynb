# %%
import pandas as pd
df = pd.read_csv("cleaned_churn_data.csv")
df
# Out:
#         Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0      22.0       0    25.0               14              4           27.0
# 1      41.0       0    28.0               28              7           13.0
# 2      47.0       1    27.0               10              2           29.0
# 3      35.0       1     9.0               12              5           17.0
# 4      53.0       0    58.0               24              9            2.0
# ...     ...     ...     ...              ...            ...            ...
# 64369  45.0       0    33.0               12              6           21.0
# 64370  37.0       1     6.0                1              5           22.0
# 64371  25.0       1    39.0               14              8           30.0
# 64372  50.0       0    18.0               19              7           22.0
# 64373  52.0       0    45.0               15              9           25.0
#
#        Subscription Type  Contract Length  Total Spend  Last Interaction  \
# 0                      0                1        598.0                 9
# 1                      2                1        584.0                20
# 2                      1                0        757.0                21
# 3                      1                2        232.0                18
# 4                      2                0        533.0                18
# ...                  ...              ...          ...               ...
# 64369                  0                2        947.0                14
# 64370                  2                0        923.0                 9
# 64371                  1                1        327.0                20
# 64372                  2                1        540.0                13
# 64373                  2                1        696.0                22
#
#        Churn   Spend  Spend_zscore
# 0          1     Low      0.222105
# 1          0     Low      0.176779
# 2          0  Medium      0.830634
# 3          0     Low     -1.209320
# 4          0     Low     -0.020179
# ...      ...     ...           ...
# 64369      1  Medium      1.573050
# 64370      1  Medium      1.485970
# 64371      1     Low     -0.840185
# 64372      1     Low      0.006854
# 64373      1     Low      0.609314
#
# [64374 rows x 13 columns]

# %%
# training before poly
import statsmodels.api as sm

y = df['Churn']
X = df.drop(columns=['Churn', 'Spend'])
X = X.apply(pd.to_numeric, errors='coerce')
X = sm.add_constant(X)

logit_model = sm.Logit(y, X).fit()
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.400352
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Churn   No. Observations:                64374
# Model:                          Logit   Df Residuals:                    64362
# Method:                           MLE   Df Model:                           11
# Date:                Sat, 02 Aug 2025   Pseudo R-squ.:                  0.4213
# Time:                        17:04:49   Log-Likelihood:                -25772.
# converged:                       True   LL-Null:                       -44531.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.1582      3.121      1.012      0.312      -2.960       9.276
# Age                   0.0192      0.001     23.756      0.000       0.018       0.021
# Gender               -1.1275      0.023    -49.168      0.000      -1.172      -1.083
# Tenure                0.0345      0.001     50.577      0.000       0.033       0.036
# Usage Frequency      -0.0577      0.001    -44.460      0.000      -0.060      -0.055
# Support Calls         0.3245      0.004     80.598      0.000       0.317       0.332
# Payment Delay         0.2113      0.002    119.293      0.000       0.208       0.215
# Subscription Type    -0.0494      0.015     -3.261      0.001      -0.079      -0.020
# Contract Length      -0.0822      0.014     -6.040      0.000      -0.109      -0.056
# Total Spend          -0.0171      0.006     -2.961      0.003      -0.028      -0.006
# Last Interaction     -0.0008      0.001     -0.637      0.524      -0.003       0.002
# Spend_zscore          4.1552      1.487      2.794      0.005       1.240       7.070
# =====================================================================================

# %%
from sklearn.metrics import accuracy_score

y_pred_probs = logit_model.predict(X)
y_pred_labels = (y_pred_probs > 0.5).astype(int)
accuracy = accuracy_score(y, y_pred_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 82.24%

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False)
num_cols = ['Age', 'Tenure', 'Payment Delay']
poly_features = poly.fit_transform(df[num_cols])
poly_df = pd.DataFrame(poly_features, columns=poly.get_feature_names_out(num_cols))

df = pd.concat([df.reset_index(drop=True), poly_df], axis=1)
df
# Out:
#         Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0      22.0       0    25.0               14              4           27.0
# 1      41.0       0    28.0               28              7           13.0
# 2      47.0       1    27.0               10              2           29.0
# 3      35.0       1     9.0               12              5           17.0
# 4      53.0       0    58.0               24              9            2.0
# ...     ...     ...     ...              ...            ...            ...
# 64369  45.0       0    33.0               12              6           21.0
# 64370  37.0       1     6.0                1              5           22.0
# 64371  25.0       1    39.0               14              8           30.0
# 64372  50.0       0    18.0               19              7           22.0
# 64373  52.0       0    45.0               15              9           25.0
#
#        Subscription Type  Contract Length  Total Spend  Last Interaction  ...  \
# 0                      0                1        598.0                 9  ...
# 1                      2                1        584.0                20  ...
# 2                      1                0        757.0                21  ...
# 3                      1                2        232.0                18  ...
# 4                      2                0        533.0                18  ...
# ...                  ...              ...          ...               ...  ...
# 64369                  0                2        947.0                14  ...
# 64370                  2                0        923.0                 9  ...
# 64371                  1                1        327.0                20  ...
# 64372                  2                1        540.0                13  ...
# 64373                  2                1        696.0                22  ...
#
#        Spend_zscore   Age  Tenure  Payment Delay   Age^2  Age Tenure  \
# 0          0.222105  22.0    25.0           27.0   484.0       550.0
# 1          0.176779  41.0    28.0           13.0  1681.0      1148.0
# 2          0.830634  47.0    27.0           29.0  2209.0      1269.0
# 3         -1.209320  35.0     9.0           17.0  1225.0       315.0
# 4         -0.020179  53.0    58.0            2.0  2809.0      3074.0
# ...             ...   ...     ...            ...     ...         ...
# 64369      1.573050  45.0    33.0           21.0  2025.0      1485.0
# 64370      1.485970  37.0     6.0           22.0  1369.0       222.0
# 64371     -0.840185  25.0    39.0           30.0   625.0       975.0
# 64372      0.006854  50.0    18.0           22.0  2500.0       900.0
# 64373      0.609314  52.0    45.0           25.0  2704.0      2340.0
#
#        Age Payment Delay  Tenure^2  Tenure Payment Delay  Payment Delay^2
# 0                  594.0     625.0                 675.0            729.0
# 1                  533.0     784.0                 364.0            169.0
# 2                 1363.0     729.0                 783.0            841.0
# 3                  595.0      81.0                 153.0            289.0
# 4                  106.0    3364.0                 116.0              4.0
# ...                  ...       ...                   ...              ...
# 64369              945.0    1089.0                 693.0            441.0
# 64370              814.0      36.0                 132.0            484.0
# 64371              750.0    1521.0                1170.0            900.0
# 64372             1100.0     324.0                 396.0            484.0
# 64373             1300.0    2025.0                1125.0            625.0
#
# [64374 rows x 22 columns]

# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_matrix['Churn'].sort_values(ascending=False)
# Out:
# Churn                   1.000000
# Payment Delay           0.551988
# Payment Delay           0.551988
# Payment Delay^2         0.541521
# Tenure Payment Delay    0.513790
# Age Payment Delay       0.469073
# Support Calls           0.304631
# Tenure                  0.192083
# Tenure                  0.192083
# Age Tenure              0.185867
# Tenure^2                0.171232
# Age^2                   0.066217
# Age                     0.062874
# Age                     0.062874
# Last Interaction       -0.002818
# Subscription Type      -0.007738
# Contract Length        -0.017098
# Spend_zscore           -0.077340
# Total Spend            -0.077400
# Usage Frequency        -0.115098
# Gender                 -0.164549
# Name: Churn, dtype: float64

# %%
# training after adding poly
import statsmodels.api as sm

y = df['Churn']
X = df.drop(columns=['Churn', 'Spend'])
X = X.apply(pd.to_numeric, errors='coerce')
X = sm.add_constant(X)

logit_model = sm.Logit(y, X).fit()
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.383023
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Churn   No. Observations:                64374
# Model:                          Logit   Df Residuals:                    64356
# Method:                           MLE   Df Model:                           17
# Date:                Sat, 02 Aug 2025   Pseudo R-squ.:                  0.4463
# Time:                        17:04:58   Log-Likelihood:                -24657.
# converged:                       True   LL-Null:                       -44531.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.3921      2.104      1.137      0.255      -1.731       6.515
# Age                      0.0290        nan        nan        nan         nan         nan
# Gender                  -1.2018      0.035    -34.764      0.000      -1.270      -1.134
# Tenure                   0.0134        nan        nan        nan         nan         nan
# Usage Frequency         -0.0594      0.001    -45.210      0.000      -0.062      -0.057
# Support Calls            0.3311      0.003     97.032      0.000       0.324       0.338
# Payment Delay            0.1763      0.009     19.421      0.000       0.159       0.194
# Subscription Type       -0.0566      0.015     -3.742      0.000      -0.086      -0.027
# Contract Length         -0.0859      0.014     -6.157      0.000      -0.113      -0.059
# Total Spend             -0.0192      0.006     -3.438      0.001      -0.030      -0.008
# Last Interaction        -0.0005      0.001     -0.379      0.704      -0.003       0.002
# Spend_zscore             4.6977      1.451      3.239      0.001       1.855       7.541
# Age                      0.0290   3.04e+04   9.54e-07      1.000   -5.97e+04    5.97e+04
# Tenure                   0.0134        nan        nan        nan         nan         nan
# Payment Delay            0.1763      0.001    319.495      0.000       0.175       0.177
# Age^2                    0.0005   6.78e-05      6.682      0.000       0.000       0.001
# Age Tenure              -0.0002        nan        nan        nan         nan         nan
# Age Payment Delay       -0.0037      0.000    -29.507      0.000      -0.004      -0.003
# Tenure^2                -0.0006   4.22e-05    -13.178      0.000      -0.001      -0.000
# Tenure Payment Delay     0.0028        nan        nan        nan         nan         nan
# Payment Delay^2         -0.0018      0.000     -8.470      0.000      -0.002      -0.001
# ========================================================================================

# %%
from sklearn.metrics import accuracy_score

y_pred_probs = logit_model.predict(X)
y_pred_labels = (y_pred_probs > 0.5).astype(int)
accuracy = accuracy_score(y, y_pred_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 82.69%
